# %%
import seaborn as sns
import pandas as pd
sns.set(style="darkgrid")
anthem = pd.read_csv('US national anthem.csv')
#anthem = pd.read_csv('input.csv')
ax = sns.countplot(x="Words", data=anthem)

# %%
ax = sns.countplot(y="Words", data=anthem)

# %%
ax = sns.countplot(x="Words", data=anthem,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
